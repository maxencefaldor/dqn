# %% [markdown]
# # References
# - [A Deeper Look at Experience Replay](https://arxiv.org/abs/1712.01275)
# - [Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)
# - [Human Level Control Through Deep Reinforcement Learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)
# - [Double Q-Learning](https://papers.nips.cc/paper/2010/file/091d584fced301b442654dd8c23b3fc9-Paper.pdf)
# - [Deep Reinforcement Learning with Double Q-learning](https://arxiv.org/abs/1509.06461)
# - [Addressing Function Approximation Error in Actor-Critic Methods](https://arxiv.org/abs/1802.09477)
# - [Rainbow: Combining Improvements in Deep Reinforcement Learning](https://arxiv.org/abs/1710.02298)
# - [PyTorch Reinforcement Learning (DQN) Tutorial](https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html)

# %% [markdown]
# # Import

# %%
import time
import random
import math
from collections import namedtuple, deque
from itertools import count, product
import numpy as np
import matplotlib.pyplot as plt

import gym
from gym import logger
logger.set_level(gym.logger.DISABLED)
from replay_buffer import ReplayBuffer

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %% [markdown]
# # CartPole Environment

# %%
env = gym.make('CartPole-v1')

# %% [markdown]
# # Replay Buffer

# %%
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer_size = int(buffer_size)
        self.buffer = []
        self.index = 0
    
    def __len__(self):
        return len(self.buffer)
    
    def add(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.buffer_size:
            self.buffer.append(None)
        self.buffer[self.index] = Transition(state, action, reward, next_state, done)
        self.index = (self.index + 1) % self.buffer_size
    
    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

# %% [markdown]
# # Neural Network

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(4, 16)
        self.fc2 = nn.Linear(16, 16)
        self.fc3 = nn.Linear(16, 2)
    
    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# # DQN Agents

# %%
class Agent:
    def __init__(self, config, nn):
        self.gamma = config["gamma"]
        self.batch_size = config["batch_size"]
        self.replay_buffer = ReplayBuffer(config["buffer_size"])
        self.n_gradient_steps = config["n_gradient_steps"]
        self.n_actions = config["n_actions"]
        self.yield_epsilon = self.epsilon_generator(config["epsilon_max"], config["epsilon_min"], config["epsilon_decay"])
        self.epsilon = config["epsilon_max"]
        self.nn = nn
        self.criterion = torch.nn.MSELoss()
        self.optimizer = optim.Adam(self.nn.parameters(), lr=config["learning_rate"])
    
    def epsilon_generator(self, epsilon_max, epsilon_min, epsilon_decay):
        step = 0
        while True:
            epsilon = epsilon_min + (epsilon_max - epsilon_min) * math.exp(-1. * step / epsilon_decay)
            yield epsilon
            step += 1
    
    def epsilon_greedy_action(self, state):
        self.epsilon = next(self.yield_epsilon)
        if random.random() > self.epsilon:
            with torch.no_grad():
                return torch.argmax(self.nn(torch.Tensor(state))).item()
        else:
            return torch.tensor(random.randrange(self.n_actions), device=device, dtype=torch.long).item()
    
    def greedy_action(self, state):
        with torch.no_grad():
            return torch.argmax(self.nn(torch.Tensor(state))).item()
    
    def gradient_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return
        
        transitions = self.replay_buffer.sample(self.batch_size)
        batch = Transition(*zip(*transitions))
        
        state_batch = torch.stack(batch.state)
        action_batch = torch.stack(batch.action)
        reward_batch = torch.stack(batch.reward)
        next_state_batch = torch.stack(batch.next_state)
        done_batch = torch.stack(batch.done)
        
        state_action_values = self.nn(state_batch).gather(1, action_batch.unsqueeze(1))
        next_state_action_values = self.nn(next_state_batch).max(1)[0].detach()
        expected_state_action_values = reward_batch + self.gamma * next_state_action_values * (1-done_batch)
        
        loss = self.criterion(state_action_values, expected_state_action_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def train(self, env, n_episodes):
        for i_episode in range(1, n_episodes+1):
            episode_return = 0
            state = env.reset()
            for t in count():
                action = self.epsilon_greedy_action(state)
                next_state, reward, done, _ = env.step(action)
                episode_return += reward
                
                self.replay_buffer.add(torch.Tensor(state), torch.tensor(action, dtype=torch.long), torch.tensor(reward, dtype=torch.float), torch.Tensor(next_state), torch.tensor(done, dtype=torch.long))
                state = next_state
                
                for _ in range(self.n_gradient_steps):
                    self.gradient_step()
                
                if done:
                    print("Episode {:4d} : {:4d} steps | epsilon = {:4.2f} | return = {:.1f}".format(i_episode, t+1, self.epsilon, episode_return))
                    break
    
    def test(self, env, step_max):
        episode_return = 0
        state = env.reset()
        for t in count():
            env.render()
            action = self.greedy_action(state)
            next_state, reward, done, _ = env.step(action)
            episode_return += reward
            
            state = next_state

            if done or t+1 >= step_max:
                env.close()
                return episode_return
    
    def save_model(self):
        return

config = {"gamma": 0.95,
          "batch_size": 128,
          "buffer_size": 1e6,
          "n_gradient_steps": 8,
          "n_actions": 2,
          "learning_rate": 0.001,
          "epsilon_max": 1.,
          "epsilon_min": 0.1,
          "epsilon_decay": 2000}

dqn = DQN()
agent = Agent(config, dqn)

# %%
agent.train(env, 300)
# Out:
# Episode    1 :   49 steps | epsilon = 0.16 | return = 49.0
# Episode    2 :  500 steps | epsilon = 0.15 | return = 500.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-48e061cbeb43> in <module>
# ----> 1 agent.train(env, 300)
#
# <ipython-input-28-ba4edefd06bb> in train(self, env, n_episodes)
#      66
#      67                 for _ in range(self.n_gradient_steps):
# ---> 68                     self.gradient_step()
#      69
#      70                 if done:
#
# <ipython-input-28-ba4edefd06bb> in gradient_step(self)
#      45
#      46         state_action_values = self.nn(state_batch).gather(1, action_batch.unsqueeze(1))
# ---> 47         next_state_action_values = self.nn(next_state_batch).max(1)[0].detach()
#      48         expected_state_action_values = reward_batch + self.gamma * next_state_action_values * (1-done_batch)
#      49
#
# KeyboardInterrupt:

# %%
agent.test(env, 1000)
# Out:
# 220.0

# %% [markdown]
# # CartPole Swing Up Environment

# %%
class CartPoleSwingUp(gym.Wrapper):
    def __init__(self, env, **kwargs):
        super(CartPoleSwingUp, self).__init__(env, **kwargs)
        self.theta_dot_threshold = 4*np.pi

    def reset(self):
        self.env.env.state = [0, 0, np.pi, 0] + super().reset()
        self.env.env.steps_beyond_done = None
        return np.array(self.env.env.state)

    def step(self, action):
        state, reward, done, _ = super().step(action)
        x, x_dot, theta, theta_dot = state
        
        done = x < -self.x_threshold \
               or x > self.x_threshold \
               or theta_dot < -self.theta_dot_threshold \
               or theta_dot > self.theta_dot_threshold
        
        if done:
            # game over
            reward = -10.
            if self.steps_beyond_done is None:
                self.steps_beyond_done = 0
            else:
                logger.warn("You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.")
                self.steps_beyond_done += 1
        else:
            if -self.theta_threshold_radians < theta and theta < self.theta_threshold_radians:
                # pole upright
                reward = 1.
            else:
                # pole swinging
                reward = 0.

        return np.array(self.state), reward, done, {}

env = CartPoleSwingUp(gym.make('CartPole-v1'))

# %%
config = {"gamma": 0.99,
          "batch_size": 128,
          "buffer_size": 1e6,
          "n_gradient_steps": 8,
          "n_actions": 2,
          "learning_rate": 0.001,
          "epsilon_max": 1.,
          "epsilon_min": 0.01,
          "epsilon_decay": 100000}

agent = Agent(config, dqn)

# %%
agent.train(env, 1000)
# Out:
# <ipython-input-4-930d7d0cf4ac>:64: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   self.replay_buffer.add(torch.Tensor(state), torch.tensor(action, dtype=torch.long), torch.tensor(reward, dtype=torch.float), torch.Tensor(next_state), torch.tensor(done, dtype=torch.long))
# Episode    1 :  245 steps | epsilon = 1.00 | return = -10.0
# Episode    2 :  120 steps | epsilon = 1.00 | return = -10.0
# Episode    3 :  183 steps | epsilon = 0.99 | return = -10.0
# Episode    4 :  173 steps | epsilon = 0.99 | return = -10.0
# Episode    5 :  128 steps | epsilon = 0.99 | return = -10.0
# Episode    6 :  197 steps | epsilon = 0.99 | return = -10.0
# Episode    7 :  450 steps | epsilon = 0.99 | return = -10.0
# Episode    8 :  352 steps | epsilon = 0.98 | return = -10.0
# Episode    9 :   93 steps | epsilon = 0.98 | return = -10.0
# Episode   10 :  123 steps | epsilon = 0.98 | return = -10.0
# Episode   11 :  323 steps | epsilon = 0.98 | return = -10.0
# Episode   12 :  137 steps | epsilon = 0.98 | return = -10.0
# Episode   13 :  135 steps | epsilon = 0.97 | return = -10.0
# Episode   14 :  166 steps | epsilon = 0.97 | return = -10.0
# Episode   15 :  293 steps | epsilon = 0.97 | return = -10.0
# Episode   16 :  101 steps | epsilon = 0.97 | return = -10.0
# Episode   17 :   72 steps | epsilon = 0.97 | return = -10.0
# Episode   18 :  190 steps | epsilon = 0.97 | return = -10.0
# Episode   19 :  154 steps | epsilon = 0.96 | return = -10.0
# Episode   20 :  205 steps | epsilon = 0.96 | return = -10.0
# Episode   21 :  141 steps | epsilon = 0.96 | return = -10.0
# Episode   22 :   73 steps | epsilon = 0.96 | return = -10.0
# Episode   23 :  397 steps | epsilon = 0.96 | return = -4.0
# Episode   24 :  154 steps | epsilon = 0.96 | return = -10.0
# Episode   25 :   77 steps | epsilon = 0.95 | return = -10.0
# Episode   26 :   82 steps | epsilon = 0.95 | return = -10.0
# Episode   27 :  198 steps | epsilon = 0.95 | return = -10.0
# Episode   28 :  115 steps | epsilon = 0.95 | return = -10.0
# Episode   29 :  118 steps | epsilon = 0.95 | return = -10.0
# Episode   30 :   80 steps | epsilon = 0.95 | return = -10.0
# Episode   31 :  504 steps | epsilon = 0.94 | return = -2.0
# Episode   32 :  330 steps | epsilon = 0.94 | return = 12.0
# Episode   33 :  139 steps | epsilon = 0.94 | return = -10.0
# Episode   34 :  113 steps | epsilon = 0.94 | return = -10.0
# Episode   35 :  515 steps | epsilon = 0.93 | return = -10.0
# Episode   36 :  173 steps | epsilon = 0.93 | return = -10.0
# Episode   37 :   70 steps | epsilon = 0.93 | return = -10.0
# Episode   38 :   99 steps | epsilon = 0.93 | return = -10.0
# Episode   39 :  160 steps | epsilon = 0.93 | return = -10.0
# Episode   40 :   87 steps | epsilon = 0.93 | return = -10.0
# Episode   41 :  139 steps | epsilon = 0.93 | return = -10.0
# Episode   42 :   83 steps | epsilon = 0.93 | return = -10.0
# Episode   43 :   82 steps | epsilon = 0.93 | return = -10.0
# Episode   44 :   82 steps | epsilon = 0.93 | return = -10.0
# Episode   45 :  273 steps | epsilon = 0.92 | return = -10.0
# Episode   46 :  157 steps | epsilon = 0.92 | return = -10.0
# Episode   47 :  101 steps | epsilon = 0.92 | return = -10.0
# Episode   48 :  170 steps | epsilon = 0.92 | return = -10.0
# Episode   49 :  375 steps | epsilon = 0.92 | return = -10.0
# Episode   50 :  176 steps | epsilon = 0.91 | return = -10.0
# Episode   51 :  156 steps | epsilon = 0.91 | return = -10.0
# Episode   52 :   94 steps | epsilon = 0.91 | return = -10.0
# Episode   53 :   89 steps | epsilon = 0.91 | return = -10.0
# Episode   54 :  172 steps | epsilon = 0.91 | return = -10.0
# Episode   55 :  165 steps | epsilon = 0.91 | return = -10.0
# Episode   56 :  136 steps | epsilon = 0.91 | return = -10.0
# Episode   57 :  285 steps | epsilon = 0.90 | return = -10.0
# Episode   58 :   70 steps | epsilon = 0.90 | return = -10.0
# Episode   59 :  251 steps | epsilon = 0.90 | return = -10.0
# Episode   60 :  286 steps | epsilon = 0.90 | return = -10.0
# Episode   61 :  182 steps | epsilon = 0.90 | return = -10.0
# Episode   62 :  294 steps | epsilon = 0.89 | return = -10.0
# Episode   63 :   87 steps | epsilon = 0.89 | return = -10.0
# Episode   64 :  220 steps | epsilon = 0.89 | return = -10.0
# Episode   65 :  116 steps | epsilon = 0.89 | return = -10.0
# Episode   66 :   69 steps | epsilon = 0.89 | return = -10.0
# Episode   67 :  108 steps | epsilon = 0.89 | return = -10.0
# Episode   68 :   73 steps | epsilon = 0.89 | return = -10.0
# Episode   69 :  207 steps | epsilon = 0.89 | return = -10.0
# Episode   70 :  226 steps | epsilon = 0.88 | return = -10.0
# Episode   71 :  295 steps | epsilon = 0.88 | return = -10.0
# Episode   72 :  189 steps | epsilon = 0.88 | return = -10.0
# Episode   73 :  104 steps | epsilon = 0.88 | return = -10.0
# Episode   74 :   56 steps | epsilon = 0.88 | return = -10.0
# Episode   75 :  108 steps | epsilon = 0.88 | return = -10.0
# Episode   76 :  280 steps | epsilon = 0.88 | return = -10.0
# Episode   77 :  590 steps | epsilon = 0.87 | return = -2.0
# Episode   78 :   97 steps | epsilon = 0.87 | return = -10.0
# Episode   79 :  232 steps | epsilon = 0.87 | return = -10.0
# Episode   80 :  321 steps | epsilon = 0.87 | return = -10.0
# Episode   81 :  111 steps | epsilon = 0.86 | return = -10.0
# Episode   82 :  182 steps | epsilon = 0.86 | return = -10.0
# Episode   83 :  121 steps | epsilon = 0.86 | return = -10.0
# Episode   84 :  100 steps | epsilon = 0.86 | return = -10.0
# Episode   85 :  296 steps | epsilon = 0.86 | return = -10.0
# Episode   86 :   64 steps | epsilon = 0.86 | return = -10.0
# Episode   87 :  138 steps | epsilon = 0.86 | return = -10.0
# Episode   88 :   91 steps | epsilon = 0.86 | return = -10.0
# Episode   89 :  162 steps | epsilon = 0.85 | return = -10.0
# Episode   90 :   68 steps | epsilon = 0.85 | return = -10.0
# Episode   91 :  247 steps | epsilon = 0.85 | return = -10.0
# Episode   92 :  747 steps | epsilon = 0.85 | return = -10.0
# Episode   93 :  861 steps | epsilon = 0.84 | return = 3.0
# Episode   94 :  519 steps | epsilon = 0.83 | return = -10.0
# Episode   95 :  182 steps | epsilon = 0.83 | return = -10.0
# Episode   96 :  471 steps | epsilon = 0.83 | return = -10.0
# Episode   97 :   57 steps | epsilon = 0.83 | return = -10.0
# Episode   98 :   74 steps | epsilon = 0.83 | return = -10.0
# Episode   99 :   79 steps | epsilon = 0.83 | return = -10.0
# Episode  100 :   55 steps | epsilon = 0.83 | return = -10.0
# Episode  101 :  523 steps | epsilon = 0.82 | return = -10.0
# Episode  102 :  416 steps | epsilon = 0.82 | return = -10.0
# Episode  103 :  115 steps | epsilon = 0.82 | return = -10.0
# Episode  104 :   83 steps | epsilon = 0.82 | return = -10.0
# Episode  105 :  417 steps | epsilon = 0.81 | return = -10.0
# Episode  106 :  597 steps | epsilon = 0.81 | return = -10.0
# Episode  107 :  619 steps | epsilon = 0.80 | return = -10.0
# Episode  108 :  155 steps | epsilon = 0.80 | return = -10.0
# Episode  109 :  455 steps | epsilon = 0.80 | return = -10.0
# Episode  110 :   67 steps | epsilon = 0.80 | return = -10.0
# Episode  111 :  248 steps | epsilon = 0.80 | return = -10.0
# Episode  112 :   88 steps | epsilon = 0.80 | return = -10.0
# Episode  113 :  111 steps | epsilon = 0.80 | return = -10.0
# Episode  114 :  318 steps | epsilon = 0.79 | return = -10.0
# Episode  115 :  564 steps | epsilon = 0.79 | return = -10.0
# Episode  116 :  268 steps | epsilon = 0.79 | return = -10.0
# Episode  117 :   73 steps | epsilon = 0.79 | return = -10.0
# Episode  118 :   63 steps | epsilon = 0.79 | return = -10.0
# Episode  119 :  231 steps | epsilon = 0.78 | return = -10.0
# Episode  120 :  397 steps | epsilon = 0.78 | return = -10.0
# Episode  121 :  262 steps | epsilon = 0.78 | return = -10.0
# Episode  122 :  103 steps | epsilon = 0.78 | return = -10.0
# Episode  123 :   72 steps | epsilon = 0.78 | return = -10.0
# Episode  124 :  105 steps | epsilon = 0.78 | return = -10.0
# Episode  125 :  167 steps | epsilon = 0.77 | return = -10.0
# Episode  126 :  261 steps | epsilon = 0.77 | return = -10.0
# Episode  127 :  158 steps | epsilon = 0.77 | return = -10.0
# Episode  128 :  852 steps | epsilon = 0.77 | return = 1.0
# Episode  129 :   67 steps | epsilon = 0.76 | return = -10.0
# Episode  130 :  219 steps | epsilon = 0.76 | return = -10.0
# Episode  131 :   90 steps | epsilon = 0.76 | return = -10.0
# Episode  132 :  851 steps | epsilon = 0.76 | return = -10.0
# Episode  133 :  133 steps | epsilon = 0.75 | return = -10.0
# Episode  134 :  224 steps | epsilon = 0.75 | return = -10.0
# Episode  135 :  292 steps | epsilon = 0.75 | return = -10.0
# Episode  136 :   94 steps | epsilon = 0.75 | return = -10.0
# Episode  137 :  601 steps | epsilon = 0.75 | return = -10.0
# Episode  138 :  165 steps | epsilon = 0.74 | return = -10.0
# Episode  139 :  236 steps | epsilon = 0.74 | return = -10.0
# Episode  140 :   63 steps | epsilon = 0.74 | return = -10.0
# Episode  141 :  353 steps | epsilon = 0.74 | return = -10.0
# Episode  142 : 1143 steps | epsilon = 0.73 | return = -3.0
# Episode  143 :  115 steps | epsilon = 0.73 | return = -10.0
# Episode  144 :  106 steps | epsilon = 0.73 | return = -10.0
# Episode  145 :  131 steps | epsilon = 0.73 | return = -10.0
# Episode  146 :  520 steps | epsilon = 0.73 | return = -10.0
# Episode  147 :  351 steps | epsilon = 0.72 | return = -10.0
# Episode  148 :  207 steps | epsilon = 0.72 | return = -10.0
# Episode  149 :  262 steps | epsilon = 0.72 | return = -10.0
# Episode  150 :  241 steps | epsilon = 0.72 | return = -10.0
# Episode  151 :  635 steps | epsilon = 0.71 | return = -10.0
# Episode  152 :  343 steps | epsilon = 0.71 | return = -10.0
# Episode  153 :  262 steps | epsilon = 0.71 | return = -10.0
# Episode  154 :  168 steps | epsilon = 0.71 | return = -10.0
# Episode  155 :   50 steps | epsilon = 0.71 | return = -10.0
# Episode  156 :  297 steps | epsilon = 0.71 | return = -10.0
# Episode  157 :  134 steps | epsilon = 0.70 | return = -10.0
# Episode  158 :  108 steps | epsilon = 0.70 | return = -10.0
# Episode  159 :   63 steps | epsilon = 0.70 | return = -10.0
# Episode  160 :  302 steps | epsilon = 0.70 | return = -10.0
# Episode  161 :   73 steps | epsilon = 0.70 | return = -10.0
# Episode  162 :  409 steps | epsilon = 0.70 | return = -10.0
# Episode  163 :  824 steps | epsilon = 0.69 | return = -10.0
# Episode  164 :  253 steps | epsilon = 0.69 | return = -10.0
# Episode  165 :   73 steps | epsilon = 0.69 | return = -10.0
# Episode  166 :   67 steps | epsilon = 0.69 | return = -10.0
# Episode  167 :  371 steps | epsilon = 0.69 | return = -10.0
# Episode  168 :   63 steps | epsilon = 0.69 | return = -10.0
# Episode  169 :  176 steps | epsilon = 0.69 | return = -10.0
# Episode  170 :  305 steps | epsilon = 0.68 | return = -10.0
# Episode  171 :  410 steps | epsilon = 0.68 | return = -10.0
# Episode  172 :  779 steps | epsilon = 0.68 | return = -10.0
# Episode  173 :  186 steps | epsilon = 0.67 | return = -10.0
# Episode  174 :  233 steps | epsilon = 0.67 | return = -10.0
# Episode  175 :  175 steps | epsilon = 0.67 | return = -10.0
# Episode  176 :  428 steps | epsilon = 0.67 | return = -4.0
# Episode  177 :   63 steps | epsilon = 0.67 | return = -10.0
# Episode  178 :  633 steps | epsilon = 0.66 | return = -2.0
# Episode  179 :  744 steps | epsilon = 0.66 | return = -10.0
# Episode  180 :  156 steps | epsilon = 0.66 | return = -10.0
# Episode  181 :  154 steps | epsilon = 0.66 | return = -10.0
# Episode  182 :  110 steps | epsilon = 0.66 | return = -10.0
# Episode  183 :  348 steps | epsilon = 0.65 | return = -10.0
# Episode  184 :  317 steps | epsilon = 0.65 | return = -9.0
# Episode  185 :  547 steps | epsilon = 0.65 | return = -10.0
# Episode  186 :  203 steps | epsilon = 0.65 | return = -10.0
# Episode  187 :  420 steps | epsilon = 0.64 | return = -10.0
# Episode  188 :  352 steps | epsilon = 0.64 | return = -10.0
# Episode  189 :  546 steps | epsilon = 0.64 | return = -5.0
# Episode  190 :  355 steps | epsilon = 0.64 | return = -1.0
# Episode  191 :  122 steps | epsilon = 0.64 | return = -10.0
# Episode  192 :  361 steps | epsilon = 0.63 | return = -10.0
# Episode  193 :  223 steps | epsilon = 0.63 | return = -10.0
# Episode  194 :  339 steps | epsilon = 0.63 | return = -2.0
# Episode  195 :  289 steps | epsilon = 0.63 | return = 2.0
# Episode  196 :  146 steps | epsilon = 0.63 | return = -10.0
# Episode  197 :  238 steps | epsilon = 0.63 | return = -10.0
# Episode  198 :  405 steps | epsilon = 0.62 | return = -10.0
# Episode  199 :   60 steps | epsilon = 0.62 | return = -10.0
# Episode  200 :  319 steps | epsilon = 0.62 | return = -10.0
# Episode  201 :  195 steps | epsilon = 0.62 | return = -10.0
# Episode  202 :  797 steps | epsilon = 0.62 | return = -10.0
# Episode  203 :  201 steps | epsilon = 0.61 | return = -10.0
# Episode  204 :  114 steps | epsilon = 0.61 | return = -10.0
# Episode  205 :  330 steps | epsilon = 0.61 | return = -10.0
# Episode  206 :  632 steps | epsilon = 0.61 | return = 3.0
# Episode  207 :   90 steps | epsilon = 0.61 | return = -10.0
# Episode  208 :  401 steps | epsilon = 0.60 | return = -2.0
# Episode  209 :  860 steps | epsilon = 0.60 | return = -8.0
# Episode  210 :  299 steps | epsilon = 0.60 | return = -10.0
# Episode  211 :  229 steps | epsilon = 0.60 | return = -10.0
# Episode  212 :   54 steps | epsilon = 0.60 | return = -10.0
# Episode  213 :  356 steps | epsilon = 0.59 | return = -10.0
# Episode  214 :  123 steps | epsilon = 0.59 | return = -10.0
# Episode  215 :  628 steps | epsilon = 0.59 | return = -10.0
# Episode  216 :  296 steps | epsilon = 0.59 | return = -10.0
# Episode  217 :  277 steps | epsilon = 0.59 | return = -10.0
# Episode  218 :  244 steps | epsilon = 0.59 | return = -10.0
# Episode  219 :  184 steps | epsilon = 0.58 | return = -10.0
# Episode  220 :  550 steps | epsilon = 0.58 | return = -10.0
# Episode  221 :  427 steps | epsilon = 0.58 | return = -10.0
# Episode  222 :  280 steps | epsilon = 0.58 | return = -10.0
# Episode  223 :  197 steps | epsilon = 0.58 | return = -10.0
# Episode  224 :  271 steps | epsilon = 0.57 | return = -10.0
# Episode  225 :  843 steps | epsilon = 0.57 | return = -10.0
# Episode  226 :  308 steps | epsilon = 0.57 | return = -10.0
# Episode  227 :  213 steps | epsilon = 0.57 | return = -10.0
# Episode  228 :  118 steps | epsilon = 0.57 | return = -10.0
# Episode  229 :  237 steps | epsilon = 0.56 | return = -10.0
# Episode  230 : 2721 steps | epsilon = 0.55 | return = 27.0
# Episode  231 :  347 steps | epsilon = 0.55 | return = -10.0
# Episode  232 : 1285 steps | epsilon = 0.54 | return = -2.0
# Episode  233 :  209 steps | epsilon = 0.54 | return = -10.0
# Episode  234 : 1281 steps | epsilon = 0.53 | return = -10.0
# Episode  235 :  588 steps | epsilon = 0.53 | return = -3.0
# Episode  236 :  565 steps | epsilon = 0.53 | return = -10.0
# Episode  237 :  390 steps | epsilon = 0.53 | return = -10.0
# Episode  238 :  372 steps | epsilon = 0.52 | return = -10.0
# Episode  239 :  809 steps | epsilon = 0.52 | return = 17.0
# Episode  240 :  375 steps | epsilon = 0.52 | return = -10.0
# Episode  241 :  465 steps | epsilon = 0.51 | return = -10.0
# Episode  242 :  494 steps | epsilon = 0.51 | return = -10.0
# Episode  243 :  456 steps | epsilon = 0.51 | return = -10.0
# Episode  244 :  204 steps | epsilon = 0.51 | return = -10.0
# Episode  245 :  332 steps | epsilon = 0.51 | return = -10.0
# Episode  246 :  627 steps | epsilon = 0.50 | return = -3.0
# Episode  247 :  503 steps | epsilon = 0.50 | return = -4.0
# Episode  248 :  942 steps | epsilon = 0.50 | return = -10.0
# Episode  249 :  221 steps | epsilon = 0.50 | return = -10.0
# Episode  250 :  358 steps | epsilon = 0.49 | return = -5.0
# Episode  251 :  578 steps | epsilon = 0.49 | return = -5.0
# Episode  252 :  619 steps | epsilon = 0.49 | return = -6.0
# Episode  253 :  707 steps | epsilon = 0.49 | return = 0.0
# Episode  254 : 2031 steps | epsilon = 0.48 | return = -10.0
# Episode  255 : 1535 steps | epsilon = 0.47 | return = -10.0
# Episode  256 : 1200 steps | epsilon = 0.46 | return = -10.0
# Episode  257 :  971 steps | epsilon = 0.46 | return = 7.0
# Episode  258 :  792 steps | epsilon = 0.46 | return = -6.0
# Episode  259 :  635 steps | epsilon = 0.45 | return = -6.0
# Episode  260 :  898 steps | epsilon = 0.45 | return = -10.0
# Episode  261 :  491 steps | epsilon = 0.45 | return = -10.0
# Episode  262 : 1613 steps | epsilon = 0.44 | return = -4.0
# Episode  263 : 1664 steps | epsilon = 0.43 | return = 10.0
# Episode  264 : 1246 steps | epsilon = 0.43 | return = 1.0
# Episode  265 :  719 steps | epsilon = 0.42 | return = -10.0
# Episode  266 : 1414 steps | epsilon = 0.42 | return = -7.0
# Episode  267 :  708 steps | epsilon = 0.42 | return = -7.0
# Episode  268 : 3232 steps | epsilon = 0.40 | return = -10.0
# Episode  269 : 1996 steps | epsilon = 0.39 | return = -6.0
# Episode  270 : 1277 steps | epsilon = 0.39 | return = -10.0
# Episode  271 :  476 steps | epsilon = 0.39 | return = -6.0
# Episode  272 :  660 steps | epsilon = 0.39 | return = -3.0
# Episode  273 : 1661 steps | epsilon = 0.38 | return = 1.0
# Episode  274 : 1017 steps | epsilon = 0.38 | return = -2.0
# Episode  275 :  729 steps | epsilon = 0.37 | return = 0.0
# Episode  276 : 2099 steps | epsilon = 0.37 | return = -6.0
# Episode  277 : 1035 steps | epsilon = 0.36 | return = -6.0
# Episode  278 :  689 steps | epsilon = 0.36 | return = -2.0
# Episode  279 : 4218 steps | epsilon = 0.34 | return = 5.0
# Episode  280 : 1728 steps | epsilon = 0.34 | return = -10.0
# Episode  281 :  638 steps | epsilon = 0.34 | return = -4.0
# Episode  282 : 1643 steps | epsilon = 0.33 | return = 4.0
# Episode  283 : 5695 steps | epsilon = 0.31 | return = 68.0
# Episode  284 : 1704 steps | epsilon = 0.31 | return = 0.0
# Episode  285 : 4465 steps | epsilon = 0.30 | return = 7.0
# Episode  286 :  722 steps | epsilon = 0.29 | return = -10.0
# Episode  287 :  578 steps | epsilon = 0.29 | return = -10.0
# Episode  288 : 4293 steps | epsilon = 0.28 | return = 13.0
# Episode  289 :  655 steps | epsilon = 0.28 | return = -5.0
# Episode  290 : 2271 steps | epsilon = 0.27 | return = 5.0
# Episode  291 : 1015 steps | epsilon = 0.27 | return = -10.0
# Episode  292 : 1270 steps | epsilon = 0.27 | return = 0.0
# Episode  293 :  918 steps | epsilon = 0.26 | return = -5.0
# Episode  294 : 1004 steps | epsilon = 0.26 | return = -10.0
# Episode  295 : 1485 steps | epsilon = 0.26 | return = -1.0
# Episode  296 :  526 steps | epsilon = 0.26 | return = -10.0
# Episode  297 : 1275 steps | epsilon = 0.25 | return = -10.0
# Episode  298 : 1474 steps | epsilon = 0.25 | return = -10.0
# Episode  299 :  576 steps | epsilon = 0.25 | return = -10.0
# Episode  300 :  995 steps | epsilon = 0.25 | return = 12.0
# Episode  301 :  604 steps | epsilon = 0.24 | return = 10.0
# Episode  302 : 1456 steps | epsilon = 0.24 | return = -4.0
# Episode  303 :  383 steps | epsilon = 0.24 | return = -6.0
# Episode  304 :  915 steps | epsilon = 0.24 | return = -10.0
# Episode  305 :  746 steps | epsilon = 0.24 | return = -2.0
# Episode  306 :  718 steps | epsilon = 0.24 | return = -10.0
# Episode  307 :  726 steps | epsilon = 0.23 | return = -10.0
# Episode  308 : 1404 steps | epsilon = 0.23 | return = 2.0
# Episode  309 :  519 steps | epsilon = 0.23 | return = -6.0
# Episode  310 :  387 steps | epsilon = 0.23 | return = 2.0
# Episode  311 :  749 steps | epsilon = 0.23 | return = -10.0
# Episode  312 :  300 steps | epsilon = 0.23 | return = -10.0
# Episode  313 :  566 steps | epsilon = 0.22 | return = -10.0
# Episode  314 :  587 steps | epsilon = 0.22 | return = 4.0
# Episode  315 :  474 steps | epsilon = 0.22 | return = -10.0
# Episode  316 : 1156 steps | epsilon = 0.22 | return = -7.0
# Episode  317 : 1334 steps | epsilon = 0.22 | return = -10.0
# Episode  318 :  755 steps | epsilon = 0.22 | return = -7.0
# Episode  319 : 1132 steps | epsilon = 0.21 | return = -10.0
# Episode  320 :  975 steps | epsilon = 0.21 | return = 0.0
# Episode  321 :  710 steps | epsilon = 0.21 | return = -10.0
# Episode  322 :  864 steps | epsilon = 0.21 | return = -10.0
# Episode  323 :  398 steps | epsilon = 0.21 | return = -10.0
# Episode  324 :  888 steps | epsilon = 0.21 | return = -10.0
# Episode  325 :  713 steps | epsilon = 0.20 | return = -2.0
# Episode  326 : 1016 steps | epsilon = 0.20 | return = -2.0
# Episode  327 :  496 steps | epsilon = 0.20 | return = -3.0
# Episode  328 :  297 steps | epsilon = 0.20 | return = -5.0
# Episode  329 : 1517 steps | epsilon = 0.20 | return = -2.0
# Episode  330 : 2759 steps | epsilon = 0.19 | return = -4.0
# Episode  331 : 2323 steps | epsilon = 0.19 | return = 1.0
# Episode  332 :  933 steps | epsilon = 0.19 | return = -2.0
# Episode  333 : 2256 steps | epsilon = 0.18 | return = -6.0
# Episode  334 : 2007 steps | epsilon = 0.18 | return = -4.0
# Episode  335 : 1612 steps | epsilon = 0.18 | return = -2.0
# Episode  336 :  606 steps | epsilon = 0.18 | return = 0.0
# Episode  337 : 1421 steps | epsilon = 0.17 | return = -7.0
# Episode  338 : 1330 steps | epsilon = 0.17 | return = 31.0
# Episode  339 :  985 steps | epsilon = 0.17 | return = -2.0
# Episode  340 :  826 steps | epsilon = 0.17 | return = -7.0
# Episode  341 : 1047 steps | epsilon = 0.17 | return = 10.0
# Episode  342 :  823 steps | epsilon = 0.17 | return = 2.0
# Episode  343 :  845 steps | epsilon = 0.16 | return = 1.0
# Episode  344 : 1942 steps | epsilon = 0.16 | return = -2.0
# Episode  345 : 1294 steps | epsilon = 0.16 | return = 0.0
# Episode  346 : 2079 steps | epsilon = 0.16 | return = -10.0
# Episode  347 : 3452 steps | epsilon = 0.15 | return = -1.0
# Episode  348 : 1000 steps | epsilon = 0.15 | return = -2.0
# Episode  349 : 1841 steps | epsilon = 0.15 | return = -3.0
# Episode  350 :  444 steps | epsilon = 0.15 | return = -2.0
# Episode  351 :  483 steps | epsilon = 0.15 | return = -5.0
# Episode  352 :  704 steps | epsilon = 0.15 | return = 2.0
# Episode  353 :  459 steps | epsilon = 0.14 | return = -7.0
# Episode  354 :  918 steps | epsilon = 0.14 | return = 11.0
# Episode  355 :  691 steps | epsilon = 0.14 | return = -10.0
# Episode  356 : 1763 steps | epsilon = 0.14 | return = 3.0
# Episode  357 : 1494 steps | epsilon = 0.14 | return = -10.0
# Episode  358 : 1338 steps | epsilon = 0.14 | return = -4.0
# Episode  359 : 1507 steps | epsilon = 0.13 | return = 22.0
# Episode  360 :  834 steps | epsilon = 0.13 | return = -10.0
# Episode  361 : 1046 steps | epsilon = 0.13 | return = 4.0
# Episode  362 : 1952 steps | epsilon = 0.13 | return = -10.0
# Episode  363 :  733 steps | epsilon = 0.13 | return = -10.0
# Episode  364 :  794 steps | epsilon = 0.13 | return = -10.0
# Episode  365 : 1451 steps | epsilon = 0.13 | return = 2.0
# Episode  366 : 1664 steps | epsilon = 0.12 | return = 24.0
# Episode  367 : 1228 steps | epsilon = 0.12 | return = -6.0
# Episode  368 : 2220 steps | epsilon = 0.12 | return = 2.0
# Episode  369 : 1779 steps | epsilon = 0.12 | return = 19.0
# Episode  370 :  781 steps | epsilon = 0.12 | return = -3.0
# Episode  371 : 1037 steps | epsilon = 0.12 | return = -6.0
# Episode  372 :  851 steps | epsilon = 0.12 | return = -7.0
# Episode  373 :  773 steps | epsilon = 0.11 | return = -10.0
# Episode  374 : 1173 steps | epsilon = 0.11 | return = 13.0
# Episode  375 : 1593 steps | epsilon = 0.11 | return = -10.0
# Episode  376 :  348 steps | epsilon = 0.11 | return = -4.0
# Episode  377 : 1191 steps | epsilon = 0.11 | return = 46.0
# Episode  378 : 1043 steps | epsilon = 0.11 | return = -10.0
# Episode  379 :  957 steps | epsilon = 0.11 | return = -10.0
# Episode  380 :  737 steps | epsilon = 0.11 | return = 47.0
# Episode  381 : 1130 steps | epsilon = 0.11 | return = -4.0
# Episode  382 :  491 steps | epsilon = 0.11 | return = -7.0
# Episode  383 : 1122 steps | epsilon = 0.11 | return = -10.0
# Episode  384 :  837 steps | epsilon = 0.10 | return = -3.0
# Episode  385 :  685 steps | epsilon = 0.10 | return = -7.0
# Episode  386 :  891 steps | epsilon = 0.10 | return = -2.0
# Episode  387 :  999 steps | epsilon = 0.10 | return = -3.0
# Episode  388 :  511 steps | epsilon = 0.10 | return = -6.0
# Episode  389 :  928 steps | epsilon = 0.10 | return = -10.0
# Episode  390 : 1194 steps | epsilon = 0.10 | return = -1.0
# Episode  391 :  684 steps | epsilon = 0.10 | return = -10.0
# Episode  392 :  289 steps | epsilon = 0.10 | return = -10.0
# Episode  393 : 1701 steps | epsilon = 0.10 | return = -10.0
# Episode  394 : 1211 steps | epsilon = 0.10 | return = 11.0
# Episode  395 :  754 steps | epsilon = 0.10 | return = -10.0
# Episode  396 :  767 steps | epsilon = 0.09 | return = -4.0
# Episode  397 : 1070 steps | epsilon = 0.09 | return = -1.0
# Episode  398 :  860 steps | epsilon = 0.09 | return = -10.0
# Episode  399 : 1049 steps | epsilon = 0.09 | return = -10.0
# Episode  400 :  478 steps | epsilon = 0.09 | return = 4.0
# Episode  401 :  848 steps | epsilon = 0.09 | return = -10.0
# Episode  402 : 1005 steps | epsilon = 0.09 | return = -5.0
# Episode  403 : 1293 steps | epsilon = 0.09 | return = -3.0
# Episode  404 :  420 steps | epsilon = 0.09 | return = -10.0
# Episode  405 :  311 steps | epsilon = 0.09 | return = -6.0
# Episode  406 :  661 steps | epsilon = 0.09 | return = -7.0
# Episode  407 : 1009 steps | epsilon = 0.09 | return = -10.0
# Episode  408 :  535 steps | epsilon = 0.09 | return = -10.0
# Episode  409 :  497 steps | epsilon = 0.09 | return = -10.0
# Episode  410 :  663 steps | epsilon = 0.09 | return = -10.0
# Episode  411 :  849 steps | epsilon = 0.09 | return = 1.0
# Episode  412 : 1071 steps | epsilon = 0.08 | return = -1.0
# Episode  413 : 2689 steps | epsilon = 0.08 | return = -4.0
# Episode  414 : 3278 steps | epsilon = 0.08 | return = -1.0
# Episode  415 : 1864 steps | epsilon = 0.08 | return = 8.0
# Episode  416 : 1408 steps | epsilon = 0.08 | return = -10.0
# Episode  417 : 3166 steps | epsilon = 0.08 | return = 6.0
# Episode  418 :  605 steps | epsilon = 0.08 | return = -1.0
# Episode  419 : 1475 steps | epsilon = 0.07 | return = 6.0
# Episode  420 : 4484 steps | epsilon = 0.07 | return = 16.0
# Episode  421 :  548 steps | epsilon = 0.07 | return = -6.0
# Episode  422 : 1040 steps | epsilon = 0.07 | return = -2.0
# Episode  423 : 5540 steps | epsilon = 0.07 | return = -3.0
# Episode  424 :  888 steps | epsilon = 0.07 | return = -10.0
# Episode  425 : 1341 steps | epsilon = 0.07 | return = -10.0
# Episode  426 :  860 steps | epsilon = 0.07 | return = -10.0
# Episode  427 : 3490 steps | epsilon = 0.06 | return = -10.0
# Episode  428 :  722 steps | epsilon = 0.06 | return = -4.0
# Episode  429 : 3040 steps | epsilon = 0.06 | return = -10.0
# Episode  430 : 3315 steps | epsilon = 0.06 | return = -10.0
# Episode  431 : 1100 steps | epsilon = 0.06 | return = 13.0
# Episode  432 :  881 steps | epsilon = 0.06 | return = -10.0
# Episode  433 : 5500 steps | epsilon = 0.06 | return = -5.0
# Episode  434 : 1198 steps | epsilon = 0.06 | return = -10.0
# Episode  435 : 2040 steps | epsilon = 0.06 | return = -10.0
# Episode  436 : 1746 steps | epsilon = 0.05 | return = -10.0
# Episode  437 : 2746 steps | epsilon = 0.05 | return = -10.0
# Episode  438 : 1206 steps | epsilon = 0.05 | return = -10.0
# Episode  439 : 4331 steps | epsilon = 0.05 | return = -2.0
# Episode  440 : 3200 steps | epsilon = 0.05 | return = 3.0
# Episode  441 : 2629 steps | epsilon = 0.05 | return = 4.0
# Episode  442 : 1286 steps | epsilon = 0.05 | return = -4.0
# Episode  443 : 4626 steps | epsilon = 0.05 | return = 0.0
# Episode  444 : 1704 steps | epsilon = 0.05 | return = 8.0
# Episode  445 : 4183 steps | epsilon = 0.04 | return = -3.0
# Episode  446 : 1116 steps | epsilon = 0.04 | return = 0.0
# Episode  447 :  751 steps | epsilon = 0.04 | return = -6.0
# Episode  448 : 15233 steps | epsilon = 0.04 | return = 7.0
# Episode  449 : 1132 steps | epsilon = 0.04 | return = -4.0
# Episode  450 : 1499 steps | epsilon = 0.04 | return = 28.0
# Episode  451 : 1365 steps | epsilon = 0.04 | return = 8.0
# Episode  452 :  308 steps | epsilon = 0.04 | return = 2.0
# Episode  453 : 1715 steps | epsilon = 0.04 | return = 56.0
# Episode  454 : 1145 steps | epsilon = 0.04 | return = -5.0
# Episode  455 : 1690 steps | epsilon = 0.04 | return = -5.0
# Episode  456 :  605 steps | epsilon = 0.04 | return = 50.0
# Episode  457 : 1072 steps | epsilon = 0.04 | return = -6.0
# Episode  458 : 1165 steps | epsilon = 0.04 | return = -3.0
# Episode  459 :  515 steps | epsilon = 0.04 | return = -6.0
# Episode  460 :  630 steps | epsilon = 0.04 | return = 3.0
# Episode  461 :  559 steps | epsilon = 0.04 | return = -2.0
# Episode  462 : 1067 steps | epsilon = 0.03 | return = 11.0
# Episode  463 :  406 steps | epsilon = 0.03 | return = -7.0
# Episode  464 : 5170 steps | epsilon = 0.03 | return = 54.0
# Episode  465 : 6785 steps | epsilon = 0.03 | return = 34.0
# Episode  466 : 1265 steps | epsilon = 0.03 | return = 0.0
# Episode  467 : 2179 steps | epsilon = 0.03 | return = 5.0
# Episode  468 : 1445 steps | epsilon = 0.03 | return = 17.0
# Episode  469 :  633 steps | epsilon = 0.03 | return = 4.0
# Episode  470 :  660 steps | epsilon = 0.03 | return = -2.0
# Episode  471 : 91552 steps | epsilon = 0.02 | return = -10.0
# Episode  472 : 3880 steps | epsilon = 0.02 | return = 23.0
# Episode  473 : 3583 steps | epsilon = 0.02 | return = 0.0
# Episode  474 : 15098 steps | epsilon = 0.02 | return = -4.0
# Episode  475 : 1646 steps | epsilon = 0.02 | return = -7.0
# Episode  476 :  699 steps | epsilon = 0.02 | return = -4.0

# %%
agent.test(env, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83d2661c1c8e> in <module>
# ----> 1 agent.test(env, 1000)
#
# NameError: name 'agent' is not defined
